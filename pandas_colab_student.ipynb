# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaviii04/Machine-Learning-Labs/blob/main/pandas_colab_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧑‍🎓 Student Version — Solutions Removed
# - Use the reflection prompts and hints.
# - Your instructor will share solutions separately.

# %%
REVEAL_SOLUTIONS = False
print('Solutions are hidden in the Student Version.')
# Out:
# Solutions are hidden in the Student Version.

# %% [markdown]
# # Pandas in Google Colab — 2-Hour Hands-On (+ Advanced & Capstone)
# **With Reflection Prompts After Each Section**
# **Last updated:** 2025-08-15
#
# Run top-to-bottom. Attempt **Exercises**, then write your **✍️ Analysis** under each section.

# %% [markdown]
# ## 0) Setup & Load the **tips** dataset (10m)

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
pd.set_option('display.max_rows', 10); pd.set_option('display.precision', 3)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
tips = pd.read_csv(url); tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print("Shape:", tips.shape)
print("\nInfo:"); print(tips.info())
print("\nDescribe:"); display(tips.describe(include='all'))
# Out:
# Shape: (244, 7)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None
#
# Describe:
#         total_bill      tip   sex smoker  day    time    size
# count      244.000  244.000   244    244  244     244  244.00
# unique         NaN      NaN     2      2    4       2     NaN
# top            NaN      NaN  Male     No  Sat  Dinner     NaN
# freq           NaN      NaN   157    151   87     176     NaN
# mean        19.786    2.998   NaN    NaN  NaN     NaN    2.57
# ...            ...      ...   ...    ...  ...     ...     ...
# min          3.070    1.000   NaN    NaN  NaN     NaN    1.00
# 25%         13.348    2.000   NaN    NaN  NaN     NaN    2.00
# 50%         17.795    2.900   NaN    NaN  NaN     NaN    2.00
# 75%         24.127    3.562   NaN    NaN  NaN     NaN    3.00
# max         50.810   10.000   NaN    NaN  NaN     NaN    6.00
#
# [11 rows x 7 columns]

# %% [markdown]
# **Columns**: `total_bill` (float), `tip` (float), `sex` (str), `smoker` (str), `day` (str), `time` (str), `size` (int)

# %% [markdown]
# ### ✅ Exercise 0
# 1) Unique `day`, `time`. 2) Count duplicates. 3) Averages of `total_bill`, `tip`.

# %% [markdown]
# **Hints:**
# - Concept: inspect levels and duplicates.
# - API: `unique`, `duplicated`, `mean`.

# %%
# YOUR WORK: Exercise 0
unique_days= tips['day'].unique()
unique_time=tips['time'].unique()

print("Unique Days:"," , ".join(unique_days))
print("Unique time:"," , ".join(unique_time))

dup=tips.duplicated().sum()
print("Duplicates:",dup)

avg_bill=tips['total_bill'].mean()
avg_tip=tips['tip'].mean()

print("Average bill:", avg_bill, "\nAverage tips:",avg_tip)
# Out:
# Unique Days: Sun , Sat , Thur , Fri
# Unique time: Dinner , Lunch
# Duplicates: 1
# Average bill: 19.78594262295082
# Average tips: 2.99827868852459

# %% [markdown]
# ### ✍️ Analysis (Setup & Load) — 3–5 sentences
# - What columns and dtypes did you observe? Any surprises?
# - Is the dataset balanced across `day` and `time`? Cite one count.
# - One risk if you skip an initial audit here.
#
# 1. Columns include numeric (total_bill, tip, size) and non-numeric (sex, smoker, day, time).
#
# 2. Dataset is slightly unbalanced: Dinner occurs more than Lunch.
#
# 3. Skipping an audit risks missing duplicates or inconsistent data.
#
# ### 🔎 Quick checks
# - Report the shape (rows, cols).
# - Name 1 non-numeric dtype and why it matters.
#
# 1. Shape: 244 × 7
#
# 2. Non-numeric: day (object), can’t compute mean directly.
#
# ### ➕ Extension (pick one)
# - Tweak display options and note the effect.
# - Compute `value_counts()` on `day` or `time`.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
tips["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# ## 1) Import & Core Manipulation (20m)

# %%
tips[['total_bill','tip']].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
tips.iloc[0:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.loc[tips['day']=='Sun', ['total_bill','tip','size']].head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
tips.query("time=='Lunch' and smoker=='Yes'").head()
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 83        32.68  5.00    Male    Yes  Thur  Lunch     2
# 138       16.00  2.00    Male    Yes  Thur  Lunch     2
# 191       19.81  4.19  Female    Yes  Thur  Lunch     2
# 192       28.44  2.56    Male    Yes  Thur  Lunch     2

# %%
tips.sort_values(['total_bill','tip'], ascending=[False, True]).head()
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 156       48.17   5.00  Male     No  Sun  Dinner     6
# 182       45.35   3.50  Male    Yes  Sun  Dinner     3

# %%
tips = tips.assign(tip_pct = tips['tip']/tips['total_bill'],
                         tip_per_person = tips['tip']/tips['size']); tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_pct  tip_per_person
# 0       16.99  1.01  Female     No  Sun  Dinner     2    0.059           0.505
# 1       10.34  1.66    Male     No  Sun  Dinner     3    0.161           0.553
# 2       21.01  3.50    Male     No  Sun  Dinner     3    0.167           1.167
# 3       23.68  3.31    Male     No  Sun  Dinner     2    0.140           1.655
# 4       24.59  3.61  Female     No  Sun  Dinner     4    0.147           0.902

# %% [markdown]
# ### ✅ Exercise 1
# Filter `day='Sat' & size≥3`, add `bill_per_person`, sort desc, show top 5.

# %% [markdown]
# **Hints:**
# - Concept: filter → compute → sort.
# - API: boolean mask / `.query`, `.assign`, `.sort_values`.

# %%
# YOUR WORK: Exercise 1
filtered= (tips[(tips['day']=='Sat')&(tips['size']>=3)]
           .assign(bill_per_person=tips['total_bill']/tips['size'])
           .sort_values('bill_per_person', ascending=False)
           .head())
print(filtered)
# Out:
#      total_bill    tip     sex smoker  day    time  size  tip_pct  \
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3    0.197
# 102       44.30   2.50  Female    Yes  Sat  Dinner     3    0.056
# 212       48.33   9.00    Male     No  Sat  Dinner     4    0.186
# 59        48.27   6.73    Male     No  Sat  Dinner     4    0.139
# 238       35.83   4.67  Female     No  Sat  Dinner     3    0.130
#
#      tip_per_person  bill_per_person
# 170           3.333           16.937
# 102           0.833           14.767
# 212           2.250           12.082
# 59            1.683           12.068
# 238           1.557           11.943

# %% [markdown]
# ### ✍️ Analysis (Import & Manipulation) — 3–5 sentences
# - Which 2 columns seem most associated with `tip`? Support with a stat.
# - Explain one filter you wrote in plain English.
# - One thing you might compute next.
#
# 1. The total_bill column and size is associated with tip.The co-relation between the total_bill VS tip and zise vs tip is positive.
# 2. tips[tips["day"] == "Sat"] here we say the tip of the tip when it is saturday.
# 3. We compute the average tip percentage by day to know which day there is more tip.
#
# ### 🔎 Quick checks
# - Show first 3 rows of your filtered frame.
# - Name one new column and its formula.
#
# 1. New column: tip_pct = tip / total_bill * 100 (tip as a percentage of total bill)

# %%
print(filtered.head(3))
# Out:
#      total_bill   tip     sex smoker  day    time  size  tip_pct  \
# 170       50.81  10.0    Male    Yes  Sat  Dinner     3    0.197
# 102       44.30   2.5  Female    Yes  Sat  Dinner     3    0.056
# 212       48.33   9.0    Male     No  Sat  Dinner     4    0.186
#
#      tip_per_person  bill_per_person
# 170           3.333           16.937
# 102           0.833           14.767
# 212           2.250           12.082

# %% [markdown]
# ### ➕ Extension (pick one)
# - Rewrite a filter via `.query` vs mask; compare readability.
# - Change a sort order and predict effect.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
# Using mask
mask = (tips["day"] == "Sat") & (tips["tip"] > 5)
filtered1 = tips[mask]
print("Using mask\n",filtered1.head(5))

# Using .query
filtered2 = tips.query('day == "Sat" and tip > 5')
print("Using query\n",filtered2.head())
# Out:
# Using mask
#       total_bill    tip   sex smoker  day    time  size  tip_pct  \
# 23        39.42   7.58  Male     No  Sat  Dinner     4    0.192
# 59        48.27   6.73  Male     No  Sat  Dinner     4    0.139
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3    0.197
# 211       25.89   5.16  Male    Yes  Sat  Dinner     4    0.199
# 212       48.33   9.00  Male     No  Sat  Dinner     4    0.186
#
#      tip_per_person
# 23            1.895
# 59            1.683
# 170           3.333
# 211           1.290
# 212           2.250
# Using query
#       total_bill    tip   sex smoker  day    time  size  tip_pct  \
# 23        39.42   7.58  Male     No  Sat  Dinner     4    0.192
# 59        48.27   6.73  Male     No  Sat  Dinner     4    0.139
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3    0.197
# 211       25.89   5.16  Male    Yes  Sat  Dinner     4    0.199
# 212       48.33   9.00  Male     No  Sat  Dinner     4    0.186
#
#      tip_per_person
# 23            1.895
# 59            1.683
# 170           3.333
# 211           1.290
# 212           2.250

# %% [markdown]
# ## 2) Cleaning & Preprocessing (15m)

# %%
tips['sex']=tips['sex'].astype('category')
tips['smoker']=tips['smoker'].astype('category')
tips['day']=tips['day'].astype('category')
tips['time']=tips['time'].astype('category'); tips.dtypes
# Out:
# total_bill         float64
# tip                float64
# sex               category
# smoker            category
# day               category
# time              category
# size                 int64
# tip_pct            float64
# tip_per_person     float64
# dtype: object

# %%
tips['server_name'] = [' Alice ', 'Bob', 'ALICE', 'bob', ' Alice ', 'Bob'] * (len(tips)//6) + ['Alice']*(len(tips)%6)
tips['server_name'] = tips['server_name'].str.strip().str.title()
tips['server_name'].head()
# Out:
# 0    Alice
# 1      Bob
# 2    Alice
# 3      Bob
# 4    Alice
# Name: server_name, dtype: object

# %%
demo = tips.copy()
demo = pd.concat([demo, demo.iloc[0:2]], ignore_index=True)
print("Before:", demo.shape, "After:", demo.drop_duplicates().shape)
# Out:
# Before: (246, 10) After: (243, 10)

# %% [markdown]
# ### ✅ Exercise 2
# 1) Ensure `size` is int64. 2) Build `tips_clean` with selected cols. 3) Verify no duplicates.

# %% [markdown]
# **Hints:**
# - Concept: enforce types, subset columns, dedup.
# - API: `.astype`, column lists, `.drop_duplicates`.

# %%
# YOUR WORK: Exercise 2
tips['size']=tips['size'].astype('int64')
print("Type of size:",tips['size'].dtypes)

col_list=['total_bill','tip','day','time','size']

tips_clean=tips[col_list].copy()
print(tips_clean.drop_duplicates())

after=tips_clean.drop_duplicates().shape[0]
before=tips_clean.shape[0]
print("\n",before-after)
# Out:
# Type of size: int64
#      total_bill   tip   day    time  size
# 0         16.99  1.01   Sun  Dinner     2
# 1         10.34  1.66   Sun  Dinner     3
# 2         21.01  3.50   Sun  Dinner     3
# 3         23.68  3.31   Sun  Dinner     2
# 4         24.59  3.61   Sun  Dinner     4
# ..          ...   ...   ...     ...   ...
# 239       29.03  5.92   Sat  Dinner     3
# 240       27.18  2.00   Sat  Dinner     2
# 241       22.67  2.00   Sat  Dinner     2
# 242       17.82  1.75   Sat  Dinner     2
# 243       18.78  3.00  Thur  Dinner     2
#
# [243 rows x 5 columns]
#
#  1

# %% [markdown]
# ### ✍️ Analysis (Cleaning & Preprocessing) — 3–5 sentences
# - Which dtype changes did you apply and why?
# - Did you handle duplicates? How many?
# - One naming or string normalization you made.
#
# 1. I applied int64
# 2. handeled duplicates using .drop_duplicates, and i had 1 duplicate
# 3. .str.strip().str.title()
#
# ### 🔎 Quick checks
# - Print memory usage pre/post for 1 cast.
# - Confirm duplicates=0 in `tips_clean`.

# %%
print("Memory usage before cast:")
print(tips.memory_usage(deep=True))

tips_clean = tips.drop_duplicates()
print("\nDuplicates after cleaning:", tips_clean.duplicated().sum())

tips_clean['size'] = tips_clean['size'].astype('int32')
print("\nMemory usage after casting 'size' to int32:")
print(tips_clean.memory_usage(deep=True))
# Out:
# Memory usage before cast:
# Index               132
# total_bill         1952
# tip                1952
# sex                 476
# smoker              471
#                   ...
# time                477
# size               1952
# tip_pct            1952
# tip_per_person     1952
# server_name       14888
# Length: 11, dtype: int64
#
# Duplicates after cleaning: 0
#
# Memory usage after casting 'size' to int32:
# Index              1944
# total_bill         1944
# tip                1944
# sex                 475
# smoker              470
#                   ...
# time                476
# size                972
# tip_pct            1944
# tip_per_person     1944
# server_name       14826
# Length: 11, dtype: int64
# /tmp/ipython-input-1167726878.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tips_clean['size'] = tips_clean['size'].astype('int32')

# %% [markdown]
# ### ➕ Extension (pick one)
# - Cast another column and report memory delta.
# - Show `.value_counts()` pre/post string cleanup.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
before_mem = tips_clean.memory_usage(deep=True).sum()
tips_clean['tip_pct'] = tips_clean['tip_pct'].astype('float32')
after_mem = tips_clean.memory_usage(deep=True).sum()
print("\nMemory delta after casting 'tip_pct' to float32:", before_mem - after_mem)

print("\nValue counts for 'day':")
print(tips_clean['day'].value_counts())
# Out:
# Memory delta after casting 'tip_pct' to float32: 972
#
# Value counts for 'day':
# day
# Sat     87
# Sun     76
# Thur    61
# Fri     19
# Name: count, dtype: int64
# /tmp/ipython-input-2575004914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tips_clean['tip_pct'] = tips_clean['tip_pct'].astype('float32')

# %% [markdown]
# ## 3) Handling Missing Data (15m)

# %%
rng = np.random.default_rng(42)
tips_na = tips_clean.copy()
mask = rng.choice([True, False], size=len(tips_na), p=[0.1, 0.9])
tips_na.loc[mask, 'tip'] = np.nan; tips_na.loc[mask, 'size'] = np.nan
tips_na.isna().sum()
# Out:
# total_bill         0
# tip               21
# sex                0
# smoker             0
# day                0
# time               0
# size              21
# tip_pct            0
# tip_per_person     0
# server_name        0
# dtype: int64

# %%
dropped = tips_na.dropna(); dropped.shape
# Out:
# (222, 10)

# %%
filled = tips_na.fillna({'tip': tips_na['tip'].median(), 'size': tips_na['size'].median()}); filled.isna().sum()
# Out:
# total_bill        0
# tip               0
# sex               0
# smoker            0
# day               0
# time              0
# size              0
# tip_pct           0
# tip_per_person    0
# server_name       0
# dtype: int64

# %%
tips_group_fill = tips_na.copy()
tips_group_fill['tip'] = tips_group_fill.groupby(['day','time'])['tip'].transform(lambda s: s.fillna(s.median()))
tips_group_fill.isna().sum()
# Out:
# /tmp/ipython-input-1629360651.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_group_fill['tip'] = tips_group_fill.groupby(['day','time'])['tip'].transform(lambda s: s.fillna(s.median()))
# total_bill         0
# tip                0
# sex                0
# smoker             0
# day                0
# time               0
# size              21
# tip_pct            0
# tip_per_person     0
# server_name        0
# dtype: int64

# %%
tips_interp = tips_na.sort_values('total_bill')
tips_interp[['total_bill','tip','size']] = tips_interp[['total_bill','tip','size']].interpolate()
tips_interp.isna().sum()
# Out:
# total_bill        0
# tip               0
# sex               0
# smoker            0
# day               0
# time              0
# size              0
# tip_pct           0
# tip_per_person    0
# server_name       0
# dtype: int64

# %% [markdown]
# ### ✅ Exercise 3
# Drop rows where both `tip` & `size` are NaN; fill `size` by rounded mean per `day`.

# %% [markdown]
# **Hints:**
# - Concept: selective drop, grouped fill.
# - API: boolean masks, `groupby().transform`, `.fillna`.

# %%
# YOUR WORK: Exercise 3
mask=tips_na['tip'].isna() & tips_na['size'].isna()
tips_cleaned=tips_na[~mask]
print(tips_cleaned)

tips_cleaned.loc[:,'size']=tips_cleaned['size'].fillna(
    tips_cleaned.groupby('day', observed=True)['size'].transform('mean').round()
)
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_pct  \
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0    0.059
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0    0.161
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0    0.167
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0    0.140
# 5         25.29  4.71    Male     No   Sun  Dinner   4.0    0.186
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 238       35.83  4.67  Female     No   Sat  Dinner   3.0    0.130
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0    0.074
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0    0.088
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0    0.098
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0    0.160
#
#      tip_per_person server_name
# 0             0.505       Alice
# 1             0.553         Bob
# 2             1.167       Alice
# 3             1.655         Bob
# 5             1.177         Bob
# ..              ...         ...
# 238           1.557       Alice
# 240           1.000       Alice
# 241           1.000       Alice
# 242           0.875       Alice
# 243           1.500       Alice
#
# [222 rows x 10 columns]

# %% [markdown]
# ### ✍️ Analysis (Missing Data) — 3–5 sentences
# - Compare `dropna` vs groupwise fill—who shifts distribution more?
# - What assumption does your fill strategy make?
# - When would interpolation be inappropriate here?
#
# 1. Using dropna() removes rows with missing values, which can shift the distribution if NaNs are not randomly scattered.
# 2. Using groupwise fill (e.g., filling missing tip by median per day) preserves the overall shape better but assumes that tips are similar within the same day.
# 3. Interpolation would be inappropriate if the data are categorical or non-time-sequential (like day or size) because the method assumes smooth changes over index.
#
# ### 🔎 Quick checks
# - Report NaN counts before vs after.
# - Cite one numeric change for `tip`.

# %%
print("NaNs before fill/drop:\n", tips_clean.isna().sum())

tips_filled = tips_clean.copy()
tips_filled['tip'] = tips_filled.groupby('day', observed=False)['tip'].transform(lambda x: x.fillna(x.median()))

print("\nNaNs after groupwise fill:\n", tips_filled.isna().sum())

print("\nTip value before vs after fill (first 3 missing indices):")
missing_indices = tips_clean['tip'].isna().to_numpy().nonzero()[0][:3]
for i in missing_indices:
    print(f"Index {i}: before=NaN, after={tips_filled.loc[i,'tip']}")
# Out:
# NaNs before fill/drop:
#  total_bill        0
# tip               0
# sex               0
# smoker            0
# day               0
# time              0
# size              0
# tip_pct           0
# tip_per_person    0
# server_name       0
# dtype: int64
#
# NaNs after groupwise fill:
#  total_bill        0
# tip               0
# sex               0
# smoker            0
# day               0
# time              0
# size              0
# tip_pct           0
# tip_per_person    0
# server_name       0
# dtype: int64
#
# Tip value before vs after fill (first 3 missing indices):

# %% [markdown]
# ### ➕ Extension (pick one)
# - Try a different group key for fill and compare MAE.
# - Plot hist pre/post fill for `tip`.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
import matplotlib.pyplot as plt

plt.hist(tips_clean['tip'].dropna(), bins=20, alpha=0.5, label='before')
plt.hist(tips_filled['tip'], bins=20, alpha=0.5, label='after fill')
plt.xlabel('Tip')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## 4) Analysis & Visualization (20m)

# %%
print("Overall tip %:", (tips['tip'].sum()/tips['total_bill'].sum()).round(3))
# Out:
# Overall tip %: 0.152

# %%
plt.figure(); plt.hist(tips['total_bill'].dropna(), bins=20)
plt.title('Histogram: total_bill'); plt.xlabel('total_bill'); plt.ylabel('Frequency'); plt.show()

# %%
plt.figure()
data = [tips.loc[tips['day']==d, 'tip'].dropna().values for d in tips['day'].cat.categories]
plt.boxplot(data, labels=list(tips['day'].cat.categories))
plt.title('Boxplot: tip by day'); plt.xlabel('day'); plt.ylabel('tip'); plt.show()
# Out:
# /tmp/ipython-input-2922675328.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=list(tips['day'].cat.categories))

# %%
plt.figure(); plt.scatter(tips['total_bill'], tips['tip'], s=tips['size']*10, alpha=0.6)
plt.title('Scatter: total_bill vs tip'); plt.xlabel('total_bill'); plt.ylabel('tip'); plt.show()

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill'] * 100
avg_tip_pct = tips.groupby('day', observed=False)['tip_pct'].mean()
plt.figure()
plt.bar(avg_tip_pct.index.astype(str), avg_tip_pct.values)
plt.title('Average tip_pct by day')
plt.xlabel('Day')
plt.ylabel('Mean tip_pct')
plt.show()

# %% [markdown]
# ### ✅ Exercise 4
# 1) Scatter: `total_bill` vs `tip_pct`. 2) Bar: median `total_bill` by `time`.

# %% [markdown]
# **Hints:**
# - Concept: relate vars via scatter; summarize via bar.
# - API: `plt.scatter`, `groupby().median` + `plt.bar`.

# %%
# YOUR WORK: Exercise 4
plt.figure();
plt.scatter(tips['total_bill'],tips['tip_pct'],s=tips['size']*10,alpha=0.6)
plt.title('Scatter: Total bill vs tip_pct');
plt.show()

median_bill =tips.groupby('time',observed=True)['total_bill'].median()
plt.figure();
plt.bar(median_bill.index.astype(str),median_bill.values)
plt.title("Bar: Total_bill vs time")
plt.xlabel('Time')
plt.ylabel('Median Total Bill')
plt.show()

# %% [markdown]
# ### ✍️ Analysis (Analysis & Visualization) — 3–5 sentences
# - State one pattern that holds across days and one that differs Lunch vs Dinner.
# - Interpret scatter: linear? heteroscedastic?
# - What would you plot next?
#
# 1. A consistent pattern: higher total_bill usually corresponds to higher tip across all days.
# 2. Differing pattern: Dinner generally has higher tips than Lunch for similar bill amounts.
# 3. Scatter interpretation: roughly linear trend, but shows heteroscedasticity (tip variability increases with bill size).
# 4. Next plot: tip percentage (tip_pct) by party size to see how group size affects tipping behavior.
#
# ### 🔎 Quick checks
# - Quote one `.describe()` stat that supports your claim.
# - Ensure axes labels/titles are informative.

# %%
tips[['total_bill','tip']].describe()
# Out:
#        total_bill      tip
# count     244.000  244.000
# mean       19.786    2.998
# std         8.902    1.384
# min         3.070    1.000
# 25%        13.348    2.000
# 50%        17.795    2.900
# 75%        24.127    3.562
# max        50.810   10.000

# %% [markdown]
# ### ➕ Extension (pick one)
# - Add a follow-up chart (e.g., tip% by party size) and describe it.
# - Bucket `total_bill` and compare medians.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
plt.scatter(tips['size'], tips['tip_pct'])
plt.xlabel('Party Size')
plt.ylabel('Tip %')
plt.title('Tip Percentage by Party Size')
plt.show()

# %% [markdown]
# ## 5) Grouping & Merging (20m)

# %%
g = (tips.groupby(['day','time'], observed=True)
       .agg(count=('total_bill','size'), avg_bill=('total_bill','mean'),
            avg_tip=('tip','mean'), avg_tip_pct=('tip_pct','mean'))); g.head()
# Out:
#              count  avg_bill  avg_tip  avg_tip_pct
# day  time
# Fri  Dinner     12    19.663    2.940       15.892
#      Lunch       7    12.846    2.383       18.876
# Sat  Dinner     87    20.441    2.993       15.315
# Sun  Dinner     76    21.410    3.255       16.690
# Thur Dinner      1    18.780    3.000       15.974

# %%
def pct_above_20(s): return (s>0.20).mean()

tips.groupby('day',observed=False)['tip_pct'].apply(pct_above_20)
# Out:
# day
# Fri     1.0
# Sat     1.0
# Sun     1.0
# Thur    1.0
# Name: tip_pct, dtype: float64

# %%
day_lookup = pd.DataFrame({'day':['Thur','Fri','Sat','Sun'],'is_weekend':[False,False,True,True]})
tips_merge = tips.merge(day_lookup, on='day', how='left')
# tips_merge
tips_merge[['day','is_weekend']].drop_duplicates().sort_values('day')
# Out:
#      day  is_weekend
# 90   Fri       False
# 19   Sat        True
# 0    Sun        True
# 77  Thur       False

# %% [markdown]
# ### ✅ Exercise 5
# 1) Sum `total_bill` & `tip` by `smoker,sex`. 2) Map `time`→L/D and show pairs.

# %% [markdown]
# **Hints:**
# - Concept: summarize by groups; enrich via merge.
# - API: `groupby().agg`, `.merge`.

# %%
# YOUR WORK: Exercise 5
res=(tips.groupby(['smoker','sex'], observed=False)
    .agg(stb=('total_bill',sum),st=('tip',sum)))
print(res)
# Out:
#                    stb      st
# smoker sex
# No     Female   977.68  149.77
#        Male    1919.75  302.00
# Yes    Female   593.27   96.74
#        Male    1337.07  183.07
# /tmp/ipython-input-4247460983.py:3: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg(stb=('total_bill',sum),st=('tip',sum)))

# %% [markdown]
# ### ✍️ Analysis (Grouping & Merging) — 3–5 sentences
# - Translate one grouped table into a business insight.
# - How does `tip_pct` vs `tip` change ranking?
# - What join-key assumptions are you making?
#
# 1. Grouping by day and time shows which periods have the highest average tip percentage; for example, Saturday Dinner tends to have the largest tips, which can guide staffing or promotions.
# 2. Ranking by tip_pct can differ from ranking by raw tip, because larger bills may yield higher absolute tips even if the percentage is lower.
# 3. When merging, we assume that the join keys (day and/or time) are consistent and complete across both tables, otherwise mismatches may occur.
#
# ### 🔎 Quick checks
# - Show index/columns of grouped result.
# - Check row counts before/after a merge.

# %%
grouped = tips.groupby(['day','time'],observed=False)['tip_pct'].mean()
print(grouped.index)
print(grouped.columns if hasattr(grouped, 'columns') else "Series object, no columns")
print("Rows before merge:", len(tips))
# Out:
# MultiIndex([( 'Fri', 'Dinner'),
#             ( 'Fri',  'Lunch'),
#             ( 'Sat', 'Dinner'),
#             ( 'Sat',  'Lunch'),
#             ( 'Sun', 'Dinner'),
#             ( 'Sun',  'Lunch'),
#             ('Thur', 'Dinner'),
#             ('Thur',  'Lunch')],
#            names=['day', 'time'])
# Series object, no columns
# Rows before merge: 244

# %% [markdown]
# ### ➕ Extension (pick one)
# - Add `avg_tip_pp` and re-rank groups.
# - Outer join with `_indicator` and explain one mismatch.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
# Compute average tip per person
tips['avg_tip_pp'] = tips['tip'] / tips['size']
grouped_pp = tips.groupby(['day','time'], observed=False)['avg_tip_pp'].mean().sort_values(ascending=False)

# Outer join with indicator
merged = tips.merge(grouped_pp.reset_index(), on=['day','time'], how='outer', suffixes=('','_pp'), indicator=True)
print(merged['_merge'].value_counts())  # shows mismatches
# Out:
# _merge
# both          244
# right_only      2
# left_only       0
# Name: count, dtype: int64

# %% [markdown]
# ## 6) Reshaping & Pivoting (15m)

# %%
piv = tips.pivot_table(index='day', columns='time', values='tip_pct', aggfunc='mean', observed=False); piv
# Out:
# time  Dinner   Lunch
# day
# Fri   15.892  18.876
# Sat   15.315     NaN
# Sun   16.690     NaN
# Thur  15.974  16.130

# %%
long = tips[['day','time','total_bill','tip']].melt(id_vars=['day','time'], var_name='metric', value_name='value'); long.head()
# Out:
#    day    time      metric  value
# 0  Sun  Dinner  total_bill  16.99
# 1  Sun  Dinner  total_bill  10.34
# 2  Sun  Dinner  total_bill  21.01
# 3  Sun  Dinner  total_bill  23.68
# 4  Sun  Dinner  total_bill  24.59

# %% [markdown]
# ### ✅ Exercise 6
# 1) Pivot mean `total_bill` by `size`×`day`. 2) Melt back to long with `size` as id.

# %% [markdown]
# **Hints:**
# - Concept: reshape wide↔long.
# - API: `pivot_table`, `melt`.

# %%
# YOUR WORK: Exercise 6

piv=tips.pivot_table(index='size',columns='day',values='total_bill',aggfunc='mean',observed=True);
print(piv)

piv_long=piv.reset_index().melt(
    id_vars='size',
    var_name='day',
    value_name='mean_total_bill'
)
print(piv_long.head())
# Out:
# day      Fri     Sat     Sun    Thur
# size
# 1      8.580   5.160     NaN  10.070
# 2     16.322  16.837  17.560  15.157
# 3     15.980  25.509  22.184  19.160
# 4     40.170  29.876  26.688  29.950
# 5        NaN  28.150  27.000  41.190
# 6        NaN     NaN  48.170  30.383
#    size  day  mean_total_bill
# 0     1  Fri            8.580
# 1     2  Fri           16.322
# 2     3  Fri           15.980
# 3     4  Fri           40.170
# 4     5  Fri              NaN

# %% [markdown]
# ### ✍️ Analysis (Reshaping & Pivoting) — 3–5 sentences
# - When did `pivot_table` drop rows/cols vs `melt`?
# - Explain wide↔long trade-offs here.
# - Which format suits your chosen chart and why?
#
# 1. Using pivot_table can drop rows/columns if there are missing combinations of day and size, whereas melt preserves all original rows by converting wide data to long format.
# 2. Wide tables are easy for comparison across categories, while long tables are more flexible for plotting or group operations.
# 3. For bar or line charts, the long format often works better because plotting libraries expect one observation per row.
# 4. Pivot tables are convenient for quick aggregation, like mean tip by day and size, but can hide missing combinations.
#
# ### 🔎 Quick checks
# - Confirm shapes of pivot vs long tables.
# - List index/columns used in your pivot.

# %%
pivot = tips.pivot_table(index='day', columns='size', values='tip', aggfunc='mean')
long = tips.melt(id_vars=['day','time'], value_vars=['tip','total_bill'], var_name='measure', value_name='value')
print("Pivot shape:", pivot.shape)
print("Long shape:", long.shape)
print("Pivot index:", pivot.index)
print("Pivot columns:", pivot.columns)
# Out:
# Pivot shape: (4, 6)
# Long shape: (488, 4)
# Pivot index: CategoricalIndex(['Fri', 'Sat', 'Sun', 'Thur'], categories=['Fri', 'Sat', 'Sun', 'Thur'], ordered=False, dtype='category', name='day')
# Pivot columns: Index([1, 2, 3, 4, 5, 6], dtype='int64', name='size')
# /tmp/ipython-input-1874354161.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = tips.pivot_table(index='day', columns='size', values='tip', aggfunc='mean')

# %% [markdown]
# ### ➕ Extension (pick one)
# - Change `aggfunc` and compare results.
# - Add a second dimension in pivot.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
# Change aggregation to median and add second dimension (time)
pivot_med = tips.pivot_table(index='day', columns='time', values='tip', aggfunc='median')
print(pivot_med)
# Out:
# time  Dinner  Lunch
# day
# Fri     3.00    2.2
# Sat     2.75    NaN
# Sun     3.15    NaN
# Thur    3.00    2.3
# /tmp/ipython-input-2399062230.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_med = tips.pivot_table(index='day', columns='time', values='tip', aggfunc='median')

# %% [markdown]
# ## 7) Mini-Project: When are tips the most generous? (5–10m)

# %%
piv = tips.pivot_table(index='day', columns='time', values='tip_pct', aggfunc='mean', observed=False)
print(piv.stack().sort_values(ascending=False).head(5))
plt.figure(); plt.imshow(piv.values, aspect='auto')
plt.title('Mean tip_pct by day & time'); plt.xlabel('time'); plt.ylabel('day')
plt.xticks(range(len(piv.columns)), piv.columns.astype(str))
plt.yticks(range(len(piv.index)), piv.index.astype(str))
plt.colorbar(); plt.show()
# Out:
# day   time
# Fri   Lunch     18.876
# Sun   Dinner    16.690
# Thur  Lunch     16.130
#       Dinner    15.974
# Fri   Dinner    15.892
# dtype: float64

# %% [markdown]
# ### ✍️ Analysis (Mini-Project (Tips Generosity)) — 3–5 sentences
# - State your top day×time combo with mean `tip_pct`.
# - Is it robust to outliers? How to check?
# - One follow-up action for a restaurant.
#
# 1. The top day×time combination for mean tip_pct is Saturday Dinner.
# 2. This result may be influenced by outliers (very high tips); we can check robustness by computing the median tip_pct or using a boxplot to spot extreme values.
# 3. Follow-up action: the restaurant could allocate more staff during Saturday Dinner to handle higher tips and potentially busier service.
#
# ### 🔎 Quick checks
# - Show top 3 combos and their counts.
# - Confirm sample size for top combo.

# %%
combo_counts = tips.groupby(['day', 'time'],observed=False).size().sort_values(ascending=False)
print("Top 3 day×time combos:\n", combo_counts.head(3))
top_combo = combo_counts.index[0]
print("\nSample size for top combo {}: {}".format(top_combo, combo_counts.iloc[0]))
# Out:
# Top 3 day×time combos:
#  day   time
# Sat   Dinner    87
# Sun   Dinner    76
# Thur  Lunch     61
# dtype: int64
#
# Sample size for top combo ('Sat', 'Dinner'): 87

# %% [markdown]
# ### ➕ Extension (pick one)
# - Recompute using median `tip_pct`.
# - Exclude size<2 and compare ranking.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
m = tips.groupby(['day', 'time'],observed=False)['tip_pct'].median().sort_values(ascending=False)
print("Top 3 day×time combos by median tip_pct:\n", m.head(3))
t = m.index[0]
s = tips[(tips['day'] == t[0]) & (tips['time'] == t[1])].shape[0]
print(f"\nSample size for top combo {t}: {s}")
# Out:
# Top 3 day×time combos by median tip_pct:
#  day   time
# Fri   Lunch     18.773
# Sun   Dinner    16.110
# Thur  Dinner    15.974
# Name: tip_pct, dtype: float64
#
# Sample size for top combo ('Fri', 'Lunch'): 7

# %% [markdown]
# # Advanced Module — Daily Operations Coverage (~60–75m)

# %% [markdown]
# ## 8) Indexes & MultiIndex (10m)

# %%
ti = tips.set_index(['day','time']).sort_index()
ti.loc[('Sat','Dinner')].head()
# Out:
#             total_bill   tip     sex smoker  size  tip_pct  tip_per_person  \
# day time
# Sat Dinner       20.65  3.35    Male     No     3   16.223           1.117
#     Dinner       17.92  4.08    Male     No     2   22.768           2.040
#     Dinner       20.29  2.75  Female     No     2   13.553           1.375
#     Dinner       15.77  2.23  Female     No     2   14.141           1.115
#     Dinner       39.42  7.58    Male     No     4   19.229           1.895
#
#            server_name  avg_tip_pp
# day time
# Sat Dinner         Bob       1.117
#     Dinner       Alice       2.040
#     Dinner         Bob       1.375
#     Dinner       Alice       1.115
#     Dinner         Bob       1.895

# %%
ti.groupby(level=['day','time'], observed=False)['tip_pct'].mean().reset_index(name='mean_tip_pct').head()
# Out:
#    day    time  mean_tip_pct
# 0  Fri  Dinner        15.892
# 1  Fri   Lunch        18.876
# 2  Sat  Dinner        15.315
# 3  Sat   Lunch           NaN
# 4  Sun  Dinner        16.690

# %% [markdown]
# ### ✍️ Analysis (Indexes & MultiIndex) — 3–5 sentences
# - What did a MultiIndex buy you over flat columns?
# - Give one easier slice enabled by the index.
# - Any pitfalls when saving/loading with MultiIndex?
#
# 1. A MultiIndex allows hierarchical organization (e.g., day and time) so you can aggregate and access data more flexibly compared to flat columns.
# 2. One easier slice: selecting all tips for Saturday Dinner using .loc[('Sat','Dinner')] without filtering manually.
# 3. Pitfall: saving/loading with MultiIndex (e.g., CSV) may flatten or lose hierarchy, requiring set_index after reading.
#
# ### 🔎 Quick checks
# - Print `.index.names` and level dtypes.
# - Show one `.loc` label slice on multi-level.

# %%
print(piv.index.names)

print(piv.index.dtype)

if isinstance(piv.index, pd.MultiIndex):
    print(piv.loc[('Sat','Dinner')])
else:
    print(piv.loc['Sat'])
# Out:
# ['day']
# category
# time
# Dinner    15.315
# Lunch        NaN
# Name: Sat, dtype: float64

# %% [markdown]
# ### ➕ Extension (pick one)
# - Swap levels and explain slicing change.
# - Reset index and compare to original columns.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
t = ti.swaplevel('day', 'time')
print(t.head())
d = t.loc['Dinner']
print(d.head())
# Out:
#             total_bill   tip     sex smoker  size  tip_pct  tip_per_person  \
# time   day
# Dinner Fri       28.97  3.00    Male    Yes     2   10.356           1.500
#        Fri       22.49  3.50    Male     No     2   15.562           1.750
#        Fri        5.75  1.00  Female    Yes     2   17.391           0.500
#        Fri       16.32  4.30  Female    Yes     2   26.348           2.150
#        Fri       22.75  3.25  Female     No     2   14.286           1.625
#
#            server_name  avg_tip_pp
# time   day
# Dinner Fri       Alice       1.500
#        Fri         Bob       1.750
#        Fri       Alice       0.500
#        Fri         Bob       2.150
#        Fri       Alice       1.625
#      total_bill   tip     sex smoker  size  tip_pct  tip_per_person  \
# day
# Fri       28.97  3.00    Male    Yes     2   10.356           1.500
# Fri       22.49  3.50    Male     No     2   15.562           1.750
# Fri        5.75  1.00  Female    Yes     2   17.391           0.500
# Fri       16.32  4.30  Female    Yes     2   26.348           2.150
# Fri       22.75  3.25  Female     No     2   14.286           1.625
#
#     server_name  avg_tip_pp
# day
# Fri       Alice       1.500
# Fri         Bob       1.750
# Fri       Alice       0.500
# Fri         Bob       2.150
# Fri       Alice       1.625

# %% [markdown]
# ## 9) Time Series & Resampling (15m)

# %%
tips_ts = tips.copy()
tips_ts['date'] = pd.to_datetime('2024-01-01') + pd.to_timedelta(np.arange(len(tips_ts)), unit='D')
tips_ts = tips_ts.set_index('date').sort_index()
weekly = tips_ts.resample('W')[['total_bill','tip']].sum()
weekly['tip_pct'] = weekly['tip']/weekly['total_bill']
weekly['tip_pct_roll4'] = weekly['tip_pct'].rolling(4, min_periods=1).mean()
weekly.head()
# Out:
#             total_bill    tip  tip_pct  tip_pct_roll4
# date
# 2024-01-07      130.67  19.80    0.152          0.152
# 2024-01-14      136.08  19.59    0.144          0.148
# 2024-01-21      118.57  23.25    0.196          0.164
# 2024-01-28      139.17  22.08    0.159          0.163
# 2024-02-04      122.78  19.97    0.163          0.165

# %% [markdown]
# ### ✍️ Analysis (Time Series & Resampling) — 3–5 sentences
# - What trend do you see weekly vs monthly?
# - Interpret divergence between raw and rolling series.
# - Why pick `W` vs `MS`?
#
# 1. Weekly (W) resampling smooths short-term fluctuations, while monthly (MS) resampling highlights broader trends.
# 2. Divergence between raw and rolling series shows local variability; spikes in raw data are smoothed in the rolling average.
# 3. W is chosen for more granularity and detecting weekly patterns, while MS aggregates data for strategic monthly insights.
# 4. Rolling windows reduce noise, making trends easier to visualize, but can lag peaks.
#
# ### 🔎 Quick checks
# - Report min/max dates in your index.
# - State the rolling window used and its effect.

# %%
# Assuming 'date' is datetime index
print("Min date:", tips.index.min())
print("Max date:", tips.index.max())

# Rolling example
rolling_window = 4
rolling_tip = tips['tip_pct'].rolling(window=rolling_window).mean()
print("Rolling window:", rolling_window)
# Out:
# Min date: 0
# Max date: 243
# Rolling window: 4

# %% [markdown]
# ### ➕ Extension (pick one)
# - Try a different window size and compare.
# - Plot both resampled and rolling series; note one change.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
weekly = tips_ts.resample('W')[['total_bill', 'tip']].sum()
weekly['tip_pct'] = weekly['tip'] / weekly['total_bill']
weekly['tip_pct_roll4'] = weekly['tip_pct'].rolling(4, min_periods=1).mean()
plt.figure(figsize=(10,5))
plt.plot(weekly.index, weekly['tip_pct'], marker='o', label='Weekly tip_pct')
plt.plot(weekly.index, weekly['tip_pct_roll4'], marker='s', linestyle='--', label='4-week Rolling mean')
plt.title('Weekly tip_pct vs Rolling mean')
plt.xlabel('Date')
plt.ylabel('Tip Percentage')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10) Rolling & Window Ops (10m)

# %%
daily = tips_ts.resample('D')[['total_bill']].sum()
daily['roll14_med'] = daily['total_bill'].rolling(14, min_periods=1).median()
daily[['total_bill','roll14_med']].head()
# Out:
#             total_bill  roll14_med
# date
# 2024-01-01       16.99      16.990
# 2024-01-02       10.34      13.665
# 2024-01-03       21.01      16.990
# 2024-01-04       23.68      19.000
# 2024-01-05       24.59      21.010

# %% [markdown]
# ### ✍️ Analysis (Rolling & Window Ops) — 3–5 sentences
# - Why is median sometimes preferable to mean in rolling stats?
# - What happens at the edges for rolling windows?
# - When is `expanding` more suitable than `rolling`?
#
# 1. Because the median is less sensitive to outliers, giving a more robust measure of central tendency in skewed or noisy data.
# 2. At the edges, the rolling window has fewer data points than the full window size, so calculations use only the available values.
# 3. Expanding is more suitable when you want cumulative statistics from the start up to each point, rather than a fixed-size window.
#
# ### 🔎 Quick checks
# - Show first 5 non-NaN rolling results.
# - Report `min_periods` and justify it.

# %%
r = d['total_bill'].rolling(14, min_periods=1)
print(r.median().dropna().head())
print("min_periods =", r.min_periods)
# Out:
# day
# Fri    28.970
# Fri    25.730
# Fri    22.490
# Fri    19.405
# Fri    22.490
# Name: total_bill, dtype: float64
# min_periods = 1

# %% [markdown]
# ### ➕ Extension (pick one)
# - Compute an additional rolling metric (std/min) and interpret.
# - Compare 7 vs 14-day windows with one sentence.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
d=d.copy()

d['roll14_std'] = d['total_bill'].rolling(14, min_periods=1).std()
d['roll14_min'] = d['total_bill'].rolling(14, min_periods=1).min()
d[['total_bill', 'roll14_std', 'roll14_min']].head()
# Out:
#      total_bill  roll14_std  roll14_min
# day
# Fri       28.97         NaN       28.97
# Fri       22.49       4.582       22.49
# Fri        5.75      11.982        5.75
# Fri       16.32       9.879        5.75
# Fri       22.75       8.776        5.75

# %% [markdown]
# ## 11) Text Data: vectorized & regex (10m)

# %%
notes = np.array(['VIP table','Late night','Allergic: nuts','Birthday','Family','vip guest'])
tips_txt = tips.copy()
tips_txt['note'] = np.resize(notes, len(tips_txt)).astype(str)
tips_txt['is_vip'] = tips_txt['note'].str.contains('vip', case=False)
tips_txt['allergy'] = tips_txt['note'].str.extract(r'Allergic:\s*(\w+)', expand=False)
tips_txt[['note','is_vip','allergy']].head()
# Out:
#              note  is_vip allergy
# 0       VIP table    True     NaN
# 1      Late night   False     NaN
# 2  Allergic: nuts   False    nuts
# 3        Birthday   False     NaN
# 4          Family   False     NaN

# %% [markdown]
# ### ✍️ Analysis (Text / Regex) — 3–5 sentences
# - Which regex or string op gave most value here?
# - How sensitive are your results to case/spacing?
# - One potential false positive in your pattern.
#
# 1. The str.contains('vip', case=False) operation gave the most value, efficiently flagging VIP guests.
# 2. Results are sensitive to case and spacing; e.g., “VIP guest” vs “vipguest” could be missed without case=False or proper word boundaries.
# 3. One potential false positive: “viper” or any word containing “vip” would match the pattern unintentionally.
#
# ### 🔎 Quick checks
# - Print counts of a detected flag (e.g., VIP).
# - Show unique extracted tokens (e.g., allergies).

# %%
# Count of VIP flags
print("VIP count:", tips_txt['is_vip'].sum())

# Unique extracted allergy tokens
print("Unique allergies:", tips_txt['allergy'].dropna().unique())
# Out:
# VIP count: 81
# Unique allergies: ['nuts']

# %% [markdown]
# ### ➕ Extension (pick one)
# - Add a refined regex (word boundaries) and compare counts.
# - Normalize text further and re-check.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
# Refined regex with word boundaries for 'vip'
tips_txt['is_vip_refined'] = tips_txt['note'].str.contains(r'\bvip\b', case=False)
print("VIP count (refined):", tips_txt['is_vip_refined'].sum())

# Optional: normalize text (lowercase, strip spaces) and re-check
tips_txt['note_norm'] = tips_txt['note'].str.lower().str.strip()
tips_txt['is_vip_norm'] = tips_txt['note_norm'].str.contains(r'\bvip\b')
print("VIP count (normalized):", tips_txt['is_vip_norm'].sum())
# Out:
# VIP count (refined): 81
# VIP count (normalized): 81

# %% [markdown]
# ## 12) Nullable dtypes & Memory (5m)

# %%
tips_mem = tips.copy()
tips_mem['size_N'] = tips_mem['size'].astype('Int64')
tips_mem['sex_S']  = tips_mem['sex'].astype('string')
tips_mem['day_C']  = tips_mem['day'].astype('category')
tips_mem.memory_usage(deep=True)
# Out:
# Index            132
# total_bill      1952
# tip             1952
# sex              476
# smoker           471
#                ...
# server_name    14888
# avg_tip_pp      1952
# size_N          2196
# sex_S          15058
# day_C            657
# Length: 15, dtype: int64

# %% [markdown]
# ### ✍️ Analysis (Dtypes & Memory) — 3–5 sentences
# - What memory savings did `category` or `string` yield?
# - When would you avoid `category`?
# - Any effect on joins/groupbys?
#
# 1. Converting string columns like day or time to category can save substantial memory, especially for repeated labels.
# 2. Avoid category if the column has high cardinality or frequently changing values, as it may increase overhead.
# 3. Using category can speed up groupbys and joins due to integer-based internal representation, but care is needed when merging with non-categorical columns.
#
# ### 🔎 Quick checks
# - Show `memory_usage(deep=True)` before/after one cast.
# - List `.cat.categories` for one column.

# %%
# Memory usage before/after casting
mem_before = tips.memory_usage(deep=True).sum()
tips['day'] = tips['day'].astype('category')
mem_after = tips.memory_usage(deep=True).sum()
print("Memory before:", mem_before)
print("Memory after:", mem_after)

# Categories for 'day'
print("Categories in 'day':", tips['day'].cat.categories)
# Out:
# Memory before: 28813
# Memory after: 28813
# Categories in 'day': Index(['Fri', 'Sat', 'Sun', 'Thur'], dtype='object')

# %% [markdown]
# ### ➕ Extension (pick one)
# - Downcast numerics where safe and report delta.
# - Switch one feature to `Int64` and explain why.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
mem_before = tips_mem.memory_usage(deep=True).sum()
print("Memory usage before downcast:", mem_before)
tips_mem['total_bill'] = pd.to_numeric(tips_mem['total_bill'], downcast='float')
tips_mem['tip'] = pd.to_numeric(tips_mem['tip'], downcast='float')
tips_mem['size_N'] = pd.to_numeric(tips_mem['size_N'], downcast='integer')
mem_after = tips_mem.memory_usage(deep=True).sum()
print("Memory usage after downcast:", mem_after)
print("Memory delta:", mem_before - mem_after)
# Out:
# Memory usage before downcast: 46724
# Memory usage after downcast: 43064
# Memory delta: 3660

# %% [markdown]
# ## 13) I/O: CSV, Parquet, JSON, SQL (10m)

# %%
subset = tips[['total_bill','tip','day','time','size']].head(20)
subset.to_csv('tips_sample.csv', index=False)
subset.to_parquet('tips_sample.parquet', index=False)
subset.to_json('tips_sample.json', orient='records', lines=True)
import sqlite3
con = sqlite3.connect(':memory:')
subset.to_sql('tips_tbl', con, index=False, if_exists='replace')
sql_df = pd.read_sql('SELECT day, time, AVG(total_bill) AS avg_bill FROM tips_tbl GROUP BY day,time', con)
con.close(); sql_df.head()
# Out:
#    day    time  avg_bill
# 0  Sat  Dinner     20.65
# 1  Sun  Dinner     18.25

# %% [markdown]
# ### ✍️ Analysis (I/O) — 3–5 sentences
# - Which format is best for speed vs size for this table? Why?
# - Did any dtype change after round-trip?
# - When to use line-delimited JSON?
#
# 1. Parquet is best columnar storage is faster for queries and uses less disk space than CSV/JSON.
# 2. Yes after reading back from CSV/JSON/SQL, categorical or nullable type often convert to default object or float64, while Parquet preserves them.
# 3. Use line-delimited JSON when handling large datasets for streaming or row-wise processing.
#
# ### 🔎 Quick checks
# - Compare shapes from CSV/Parquet/JSON loads.
# - Show one dtype discrepancy and fix it.

# %%
print("Final columns:", tips.columns.tolist())
tips['size'] = tips['size'].astype('int64')
print("Columns after re-running step:", tips.columns.tolist())
# Out:
# Final columns: ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'tip_pct', 'tip_per_person', 'server_name', 'avg_tip_pp']
# Columns after re-running step: ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'tip_pct', 'tip_per_person', 'server_name', 'avg_tip_pp']

# %% [markdown]
# ### ➕ Extension (pick one)
# - Compress CSV (gzip) and note file size.
# - Do a small SQL query and validate results match a groupby.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']
high_tips = tips[tips['tip_pct'] > 0.2]
avg_high_tip = high_tips['tip_pct'].mean()
print("Average high tip:",avg_high_tip)

# avg_high_tip = (
#     tips
#     .assign(tip_pct=lambda df: df['tip'] / df['total_bill'])
#     .query("tip_pct > 0.2")
#     ['tip_pct']
#     .mean()
# )
# print(avg_high_tip)
# Out:
# Average high tip: 0.24804410613226133

# %% [markdown]
# ## 14) Join Patterns (10–15m)

# %%
left = tips[['day','time','size']].drop_duplicates().copy()
right = tips[['day','time','tip']].groupby(['day','time']).mean().reset_index().rename(columns={'tip':'avg_tip'})
joined = left.merge(right, on=['day','time'], how='outer', indicator=True)
joined.head()
# Out:
# /tmp/ipython-input-1235496268.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   right = tips[['day','time','tip']].groupby(['day','time']).mean().reset_index().rename(columns={'tip':'avg_tip'})
#    day    time  size  avg_tip _merge
# 0  Fri  Dinner   2.0    2.940   both
# 1  Fri  Dinner   4.0    2.940   both
# 2  Fri   Lunch   2.0    2.383   both
# 3  Fri   Lunch   1.0    2.383   both
# 4  Fri   Lunch   3.0    2.383   both

# %%
# Right-only and inner (semi-join-style)
right_only = joined.loc[joined['_merge']=='right_only', right.columns]
inner_rows = joined.loc[joined['_merge']=='both', left.columns].drop_duplicates()
len(inner_rows)
# Out:
# 22

# %%
# merge_ordered and merge_asof demos
a = pd.DataFrame({'day':['Fri','Sat','Sun'], 'rank':[1,2,3]})
b = pd.DataFrame({'day':['Thur','Sat','Sun'], 'score':[70,80,90]})
ordered = pd.merge_ordered(a, b, on='day', how='outer')
events = pd.DataFrame({'when': pd.to_datetime(['2024-01-01 10:00','2024-01-02 12:30','2024-01-04 09:00']),'event':['A','B','C']}).sort_values('when')
measures = pd.DataFrame({'when': pd.to_datetime(['2024-01-01 09:45','2024-01-02 12:00','2024-01-03 18:00','2024-01-04 08:50']),'value':[10,20,15,30]}).sort_values('when')
asof_join = pd.merge_asof(events, measures, on='when', direction='nearest', tolerance=pd.Timedelta('1H'))
ordered.head(), asof_join.head()
# Out:
# /tmp/ipython-input-961497798.py:7: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   asof_join = pd.merge_asof(events, measures, on='when', direction='nearest', tolerance=pd.Timedelta('1H'))
# (    day  rank  score
#  0   Fri   1.0    NaN
#  1   Sat   2.0   80.0
#  2   Sun   3.0   90.0
#  3  Thur   NaN   70.0,
#                   when event  value
#  0 2024-01-01 10:00:00     A     10
#  1 2024-01-02 12:30:00     B     20
#  2 2024-01-04 09:00:00     C     30)

# %% [markdown]
# ### ✍️ Analysis (Joins) — 3–5 sentences
# - Read `_indicator` results—what mismatches did you find?
# - Where would `merge_asof` fit in a real pipeline?
# - Any ordering assumptions for `merge_ordered`?
#
# 1. Rows labeled left_only exist in the left table but not in right; right_only exist in right but not in left; both matched on the join keys.
# 2. It fits when aligning events or measurements by nearest timestamp for time-series or sequential data.
# 3. Yes both DataFrames should be sorted by the key(s) to ensure correct alignment and interpolation.
#
# ### 🔎 Quick checks
# - Report counts for left/right/inner.
# - Show 2 sample rows from an anti-join.

# %%
left_count = len(joined[joined['_merge'] == 'left_only'])
right_count = len(joined[joined['_merge'] == 'right_only'])
inner_count = len(joined[joined['_merge'] == 'both'])
print(f"Left-only rows: {left_count}")
print(f"Right-only rows: {right_count}")
print(f"Inner rows: {inner_count}")
anti_join_sample = joined[joined['_merge'] == 'right_only'].head(2)
print("\nSample anti-join rows (right-only):")
print(anti_join_sample)
# Out:
# Left-only rows: 0
# Right-only rows: 2
# Inner rows: 22
#
# Sample anti-join rows (right-only):
#     day   time  size  avg_tip      _merge
# 10  Sat  Lunch   NaN      NaN  right_only
# 16  Sun  Lunch   NaN      NaN  right_only

# %% [markdown]
# ### ➕ Extension (pick one)
# - Perform a semi-join and explain the use-case.
# - Add a composite key and re-merge.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
semi_join = left.merge(right, on=['day', 'time'], how='inner')[left.columns]
print(semi_join.head())
# Out:
#    day    time  size
# 0  Sun  Dinner     2
# 1  Sun  Dinner     3
# 2  Sun  Dinner     4
# 3  Sat  Dinner     3
# 4  Sat  Dinner     2

# %% [markdown]
# ## 15) Method Chaining & `.pipe`, `.query`, `.eval` (10m)

# %%
def add_bill_per_person(df): return df.assign(bill_per_person = df['total_bill']/df['size'])
pipe_demo = (tips.query("time=='Dinner'").pipe(add_bill_per_person)
             .groupby('day').agg(mean_bill_pp=('bill_per_person','mean'),
                                 mean_tip_pct=('tip_pct','mean'))
             .sort_values('mean_bill_pp', ascending=False))
eval_demo = tips.eval('bill_pp = total_bill / size')
pipe_demo.head(), eval_demo[['total_bill','size','bill_pp']].head()
# Out:
# /tmp/ipython-input-4069205455.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('day').agg(mean_bill_pp=('bill_per_person','mean'),
# (      mean_bill_pp  mean_tip_pct
#  day
#  Thur         9.390         0.160
#  Fri          8.995         0.159
#  Sat          8.187         0.153
#  Sun          7.864         0.167,
#     total_bill  size  bill_pp
#  0       16.99     2    8.495
#  1       10.34     3    3.447
#  2       21.01     3    7.003
#  3       23.68     2   11.840
#  4       24.59     4    6.147)

# %% [markdown]
# ### ✍️ Analysis (Method Chaining) — 3–5 sentences
# - What made the chained pipeline clearer or riskier?
# - Where would you break the chain for debugging?
# - When is `.eval` useful vs risky?
#
# 1. Chaining improves readability by showing the full workflow at once but increases debugging risk due to harder inspection of intermediate results.
# 2. Break the chain after complex transformations or groupings to inspect intermediate DataFrames.
# 3. .eval is useful for concise, fast column expressions; risky if expressions use unsafe input or obscure readability.
#
# ### 🔎 Quick checks
# - Show final columns of your pipeline result.
# - Confirm idempotency by re-running.

# %%
print("Final columns:", tips.columns.tolist())
tips_final_re = tips.copy()
tips_final_re['size'] = tips_final_re['size'].astype('int64')
print("Columns after re-run:", tips_final_re.columns.tolist())
print("Idempotent check:", tips.equals(tips_final_re))
# Out:
# Final columns: ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'tip_pct', 'tip_per_person', 'server_name', 'avg_tip_pp']
# Columns after re-run: ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size', 'tip_pct', 'tip_per_person', 'server_name', 'avg_tip_pp']
# Idempotent check: True

# %% [markdown]
# ### ➕ Extension (pick one)
# - Refactor an earlier analysis into a chain; compare readability.
# - Encapsulate a step into `.pipe` and reuse it.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
tips_sorted = (
    tips.assign(tip_pct=lambda df: df['tip'] / df['total_bill'])
        .query('size > 1')
        .groupby(['day', 'time'], as_index=False, observed=False)['tip_pct']
        .mean()
        .sort_values('tip_pct', ascending=False)
)
tips_sorted.head()
# Out:
#     day    time  tip_pct
# 1   Fri   Lunch    0.183
# 4   Sun  Dinner    0.167
# 7  Thur   Lunch    0.161
# 6  Thur  Dinner    0.160
# 0   Fri  Dinner    0.159

# %% [markdown]
# ## 16) Crosstab, `cut/qcut`, `where/mask` (5–10m)

# %%
ct = pd.crosstab(tips['smoker'], tips['day'])
tips_bins = tips.copy()
tips_bins['bill_bucket'] = pd.cut(tips_bins['total_bill'], bins=[0,10,20,30,50])
bucket_mean = tips_bins.groupby('bill_bucket')['tip'].mean()
tips_q = tips.assign(q = pd.qcut(tips['tip_pct'], 4, duplicates='drop'))
ct, bucket_mean, tips_q.groupby('q')['total_bill'].mean()
# Out:
# /tmp/ipython-input-2604880072.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bucket_mean = tips_bins.groupby('bill_bucket')['tip'].mean()
# /tmp/ipython-input-2604880072.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ct, bucket_mean, tips_q.groupby('q')['total_bill'].mean()
# (day     Fri  Sat  Sun  Thur
#  smoker
#  No        4   45   57    45
#  Yes      15   42   19    17,
#  bill_bucket
#  (0, 10]     1.838
#  (10, 20]    2.455
#  (20, 30]    3.608
#  (30, 50]    4.408
#  Name: tip, dtype: float64,
#  q
#  (0.0346, 0.129]    24.933
#  (0.129, 0.155]     19.051
#  (0.155, 0.191]     17.848
#  (0.191, 0.71]      17.312
#  Name: total_bill, dtype: float64)

# %% [markdown]
# ### ✍️ Analysis (Crosstab / Bucketing) — 3–5 sentences
# - What story does your crosstab tell in one sentence?
# - How did `cut` vs `qcut` change bucket sizes?
# - When is `where` preferable to boolean indexing?
#
# 1. Non-smokers consistently outnumber smokers across all days, with the busiest tipping days being Friday and Saturday.
# 2. cut created fixed-width total_bill buckets, resulting in uneven counts per bin, whereas qcut divided tip_pct into quantiles, producing roughly equal-sized groups.
# 3. where is preferable when you want to keep the original DataFrame shape and replace non-matching values with NaN.
#
# ### 🔎 Quick checks
# - Show bucket edges and counts.
# - Verify monotonicity of bucket means if expected.

# %%
bill_cuts = pd.cut(tips['total_bill'], bins=[0, 10, 20, 30, 50])
print("Cut bucket edges:", bill_cuts.cat.categories)
print("Counts per cut bucket:\n", bill_cuts.value_counts())
tip_pct_qcuts = pd.qcut(tips['tip_pct'], 4, duplicates='drop')
print("\nQCut bucket edges:", tip_pct_qcuts.cat.categories)
print("Counts per qcut bucket:\n", tip_pct_qcuts.value_counts())
bucket_means = tips.groupby(bill_cuts,observed=False)['tip'].mean()
print("\nBucket means:\n", bucket_means)
print("Monotonic increasing?", bucket_means.is_monotonic_increasing)
# Out:
# Cut bucket edges: IntervalIndex([(0, 10], (10, 20], (20, 30], (30, 50]], dtype='interval[int64, right]')
# Counts per cut bucket:
#  total_bill
# (10, 20]    130
# (20, 30]     65
# (30, 50]     31
# (0, 10]      17
# Name: count, dtype: int64
#
# QCut bucket edges: IntervalIndex([(0.0346, 0.129], (0.129, 0.155], (0.155, 0.191], (0.191, 0.71]], dtype='interval[float64, right]')
# Counts per qcut bucket:
#  tip_pct
# (0.0346, 0.129]    61
# (0.129, 0.155]     61
# (0.155, 0.191]     61
# (0.191, 0.71]      61
# Name: count, dtype: int64
#
# Bucket means:
#  total_bill
# (0, 10]     1.838
# (10, 20]    2.455
# (20, 30]    3.608
# (30, 50]    4.408
# Name: tip, dtype: float64
# Monotonic increasing? True

# %% [markdown]
# ### ➕ Extension (pick one)
# - Swap `qcut`/`cut` and compare stats.
# - Mask outliers and re-summarize.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
Q1, Q3 = tips['tip'].quantile([0.25, 0.75])
IQR = Q3 - Q1
mask = (tips['tip'] >= Q1 - 1.5*IQR) & (tips['tip'] <= Q3 + 1.5*IQR)
tips_no_outliers = tips.loc[mask]
bill_cuts_no_outliers = pd.cut(tips_no_outliers['total_bill'], bins=[0, 10, 20, 30, 50])
bucket_means_no_outliers = tips_no_outliers.groupby(bill_cuts_no_outliers, observed=False)['tip'].mean()
print("Bucket means after masking outliers:\n", bucket_means_no_outliers)
# Out:
# Bucket means after masking outliers:
#  total_bill
# (0, 10]     1.838
# (10, 20]    2.455
# (20, 30]    3.477
# (30, 50]    3.871
# Name: tip, dtype: float64

# %% [markdown]
# ## 17) Styling & Export (5m)

# %%
sty = (tips.groupby('day')[['total_bill','tip','tip_pct']].mean().round(2)
         .style.format({'tip_pct':'{:.2%}'}).background_gradient(axis=None))
html = sty.to_html()
open('tips_report.html','w',encoding='utf-8').write(html)
'Wrote tips_report.html'
# Out:
# /tmp/ipython-input-1253526996.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sty = (tips.groupby('day')[['total_bill','tip','tip_pct']].mean().round(2)
# 'Wrote tips_report.html'

# %% [markdown]
# ### ✍️ Analysis (Styling & Export) — 3–5 sentences
# - What formatting improved readability most?
# - How would a stakeholder use this HTML report?
# - One caution about styled HTML vs raw data files.
#
# 1. The percentage formatting ({:.2%}) for tip_pct) improved readability most, as it makes relative tipping clearly interpretable at a glance.
# 2. A stakeholder could quickly scan average bills, tips, and tip percentages by day without coding, spot trends or anomalies, and share the HTML report with colleagues for decision-making or presentations.
# 3. Styled HTML is read-only and visual only, so it can’t be used directly for further analysis or calculations like raw CSV/Parquet files.
#
# ### 🔎 Quick checks
# - Open the HTML to spot issues (NA/odd values).
# - Confirm underlying numbers (pre-style) are correct.

# %%
import webbrowser
webbrowser.open('tips_report.html')
tips.groupby('day', observed=False)[['total_bill', 'tip', 'tip_pct']].mean().round(2)
# Out:
#       total_bill   tip  tip_pct
# day
# Fri        17.15  2.73     0.17
# Sat        20.44  2.99     0.15
# Sun        21.41  3.26     0.17
# Thur       17.68  2.77     0.16

# %% [markdown]
# ### ➕ Extension (pick one)
# - Add one more style and explain choice.
# - Export both styled HTML and CSV for same table.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
sty = (tips.groupby('day', observed=False)[['total_bill', 'tip', 'tip_pct']]
       .mean()
       .round(2)
       .style.format({'tip_pct': '{:.2%}'})
       .background_gradient(axis=None))
html_file = 'tips_report.html'
sty.to_html(html_file, encoding='utf-8')
print(f'Styled HTML saved to {html_file}')
csv_file = 'tips_report.csv'
tips.groupby('day', observed=False)[['total_bill', 'tip', 'tip_pct']].mean().round(2).to_csv(csv_file)
print(f'Raw CSV saved to {csv_file}')
# Out:
# Styled HTML saved to tips_report.html
# Raw CSV saved to tips_report.csv

# %% [markdown]
# # Capstone Mini-Project (Free Dataset): **Titanic Survival Analysis** (30–45m)

# %% [markdown]
# **Source:** https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
tit_url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
titanic = pd.read_csv(tit_url)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.250        S  Third
# 1         1       1  female  38.0      1      0  71.283        C  First
# 2         1       3  female  26.0      0      0   7.925        S  Third
# 3         1       1  female  35.0      1      0  53.100        S  First
# 4         0       3    male  35.0      0      0   8.050        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print("Shape:", titanic.shape)
print("\nInfo:"); print(titanic.info())
print("\nMissing values per column:"); print(titanic.isna().sum().sort_values(ascending=False).head(12))
# Out:
# Shape: (891, 15)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB
# None
#
# Missing values per column:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
#               ...
# fare             0
# parch            0
# sibsp            0
# class            0
# adult_male       0
# Length: 12, dtype: int64

# %% [markdown]
# ## A) Data Cleaning & Feature Engineering

# %%
df = titanic.copy()
for col in ['sex','class','embarked','embark_town','alive','who','deck','alone','adult_male']:
    if col in df.columns: df[col] = df[col].astype('category')
age_med = df.groupby(['sex','class'])['age'].transform('median')
df['age'] = df['age'].fillna(age_med)
if df['embark_town'].isna().any():
    mode_town = df['embark_town'].mode(dropna=True)
    if not mode_town.empty: df['embark_town'] = df['embark_town'].fillna(mode_town.iloc[0])
df['family_size'] = df['sibsp'].fillna(0) + df['parch'].fillna(0) + 1
df['fare_pp'] = df['fare'] / df['family_size']
df['deck'] = df['deck'].cat.add_categories(['Unknown']).fillna('Unknown')
bins = [0,12,18,35,50,80]; labels = ['Child','Teen','YoungAdult','MidAge','Senior']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, include_lowest=True)
df.head()
# Out:
# /tmp/ipython-input-587888411.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_med = df.groupby(['sex','class'])['age'].transform('median')
#    survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.250        S  Third
# 1         1       1  female  38.0      1      0  71.283        C  First
# 2         1       3  female  26.0      0      0   7.925        S  Third
# 3         1       1  female  35.0      1      0  53.100        S  First
# 4         0       3    male  35.0      0      0   8.050        S  Third
#
#      who adult_male     deck  embark_town alive  alone  family_size  fare_pp  \
# 0    man       True  Unknown  Southampton    no  False            2    3.625
# 1  woman      False        C    Cherbourg   yes  False            2   35.642
# 2  woman      False  Unknown  Southampton   yes   True            1    7.925
# 3  woman      False        C  Southampton   yes  False            2   26.550
# 4    man       True  Unknown  Southampton    no   True            1    8.050
#
#     age_group
# 0  YoungAdult
# 1      MidAge
# 2  YoungAdult
# 3  YoungAdult
# 4  YoungAdult

# %% [markdown]
# ### ✅ Exercise A
# Check NaNs in `age`/`embark_town`, top `family_size`, % with `fare_pp>20`.

# %% [markdown]
# **Hints:**
# - Concept: impute & feature engineer.
# - API: `groupby().transform('median')`, `.mode()`, `.cut`.

# %%
# YOUR WORK: Exercise A
nan_age = df['age'].isna().sum()
nan_embark_town = df['embark_town'].isna().sum()
print(f"Missing values - Age: {nan_age}, Embark Town: {nan_embark_town}")
top_families = df['family_size'].value_counts().head(10)
print("\nTop 10 family sizes:\n", top_families)
fare_pp_over_20 = (df['fare_pp'] > 20).sum()
total_passengers = df.shape[0]
percentage_high_fare = (fare_pp_over_20 / total_passengers) * 100
print(f"\nPercentage of passengers with fare_pp > 20: {percentage_high_fare:.2f}%")
# Out:
# Missing values - Age: 0, Embark Town: 0
#
# Top 10 family sizes:
#  family_size
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64
#
# Percentage of passengers with fare_pp > 20: 25.36%

# %% [markdown]
# ## B) Survival Patterns

# %%
overall_survival = df['survived'].mean(); print('Overall survival rate:', round(overall_survival,3))
# Out:
# Overall survival rate: 0.384

# %%
surv_by_class = df.groupby('class')['survived'].mean().reindex(['First','Second','Third'])
plt.figure(); plt.bar(surv_by_class.index.astype(str), surv_by_class.values)
plt.title('Survival Rate by Class'); plt.xlabel('class'); plt.ylabel('survival rate'); plt.show()
# Out:
# /tmp/ipython-input-3625588530.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surv_by_class = df.groupby('class')['survived'].mean().reindex(['First','Second','Third'])

# %%
piv = df.pivot_table(index='sex', columns='class', values='survived', aggfunc='mean')
plt.figure(); plt.imshow(piv.values, aspect='auto')
plt.title('Survival Rate by Sex × Class'); plt.xlabel('class'); plt.ylabel('sex')
plt.xticks(range(len(piv.columns)), piv.columns.astype(str))
plt.yticks(range(len(piv.index)), piv.index.astype(str))
plt.colorbar(); plt.show(); piv
# Out:
# /tmp/ipython-input-271380004.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   piv = df.pivot_table(index='sex', columns='class', values='survived', aggfunc='mean')
# class   First  Second  Third
# sex
# female  0.968   0.921  0.500
# male    0.369   0.157  0.135

# %% [markdown]
# ### ✅ Exercise B
# 1) Histogram of age. 2) Boxplot fare by class. 3) Bar of survival by age_group.

# %% [markdown]
# **Hints:**
# - Concept: univariate + grouped visuals.
# - API: `plt.hist`, `plt.boxplot`, `groupby().mean` + `plt.bar`.

# %%
# YOUR WORK: Exercise B
plt.figure(figsize=(8,5))
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
plt.figure(figsize=(8,5))
classes = ['First', 'Second', 'Third']
fare_by_class = [df[df['class'] == c]['fare'] for c in classes]
plt.boxplot(fare_by_class, labels=classes)
plt.title('Fare Distribution by Class')
plt.xlabel('Class')
plt.ylabel('Fare')
plt.show()
surv_by_agegroup = df.groupby('age_group')['survived'].mean()
plt.figure(figsize=(8,5))
plt.bar(surv_by_agegroup.index.astype(str), surv_by_agegroup.values, color='lightgreen', edgecolor='black')
plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# /tmp/ipython-input-2787647055.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(fare_by_class, labels=classes)
# /tmp/ipython-input-2787647055.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surv_by_agegroup = df.groupby('age_group')['survived'].mean()

# %% [markdown]
# ## C) Subgroup Discovery

# %%
grp = (df.groupby(['sex','class','embark_town'])
         .agg(n=('survived','size'), surv_rate=('survived','mean'))
         .query('n >= 25')
         .sort_values('surv_rate', ascending=False))
grp.head(10)
# Out:
# /tmp/ipython-input-1601229680.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grp = (df.groupby(['sex','class','embark_town'])
#                              n  surv_rate
# sex    class  embark_town
# female First  Cherbourg     43      0.977
#               Southampton   50      0.960
#        Second Southampton   67      0.910
#        Third  Queenstown    33      0.727
# male   First  Cherbourg     42      0.405
# female Third  Southampton   88      0.375
# male   First  Southampton   79      0.354
#        Third  Cherbourg     43      0.233
#        Second Southampton   97      0.155
#        Third  Southampton  265      0.128

# %% [markdown]
# ### ✅ Exercise C
# Families with `family_size≥4`: survival by `sex` & `class` (n + rate). Bucket `fare_pp` and compute survival per bucket.

# %% [markdown]
# **Hints:**
# - Concept: subgroup analysis with thresholds.
# - API: `groupby().agg`, `query`, `cut`.

# %%
# YOUR WORK: Exercise C
large_families = (df[df['family_size'] >= 4]
                  .groupby(['sex', 'class'])
                  .agg(n=('survived', 'size'),
                       surv_rate=('survived', 'mean'))
                  .sort_values('surv_rate', ascending=False))
print("Survival for large families (family_size >=4):\n", large_families)
fare_bins = [0, 10, 20, 30, 50, 100, 600]
fare_labels = ['0-10', '10-20', '20-30', '30-50', '50-100', '100+']
df['fare_pp_bucket'] = pd.cut(df['fare_pp'], bins=fare_bins, labels=fare_labels, include_lowest=True)
surv_by_fare_bucket = df.groupby('fare_pp_bucket')['survived'].agg(['size','mean']).rename(columns={'size':'n','mean':'surv_rate'})
print("\nSurvival by fare_pp bucket:\n", surv_by_fare_bucket)
# Out:
# Survival for large families (family_size >=4):
#                  n  surv_rate
# sex    class
# female Second  11      1.000
#        First    8      0.750
# male   First    5      0.600
#        Second   4      0.250
# female Third   33      0.242
# male   Third   30      0.067
#
# Survival by fare_pp bucket:
#                    n  surv_rate
# fare_pp_bucket
# 0-10            512      0.271
# 10-20           153      0.431
# 20-30            89      0.562
# 30-50            71      0.549
# 50-100           44      0.682
# 100+             22      0.818
# /tmp/ipython-input-1519896213.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['sex', 'class'])
# /tmp/ipython-input-1519896213.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   surv_by_fare_bucket = df.groupby('fare_pp_bucket')['survived'].agg(['size','mean']).rename(columns={'size':'n','mean':'surv_rate'})

# %% [markdown]
# ## D) Deliverables

# %%
top10 = grp.head(10).reset_index()
sty = (top10.style.format({'surv_rate':'{:.2%}'}).hide(axis='index'))
html = sty.to_html()
open('titanic_top10_survival.html','w',encoding='utf-8').write(html)
top10.to_csv('titanic_top10_survival.csv', index=False)
"Saved titanic_top10_survival.html and titanic_top10_survival.csv"
# Out:
# 'Saved titanic_top10_survival.html and titanic_top10_survival.csv'

# %% [markdown]
# ### ✍️ Analysis (Capstone — Titanic) — 3–5 sentences
# - State your main finding (who/when/context) with one number and one plot reference.
# - Name one limitation in your approach (bias, leakage, imputation).
# - Suggest a next step or feature to add.
#
# 1. Female passengers in First Class from Cherbourg had the highest survival rate among large families with 98% survival rate.
# 2. One limitation in this approach is imputation of missing ages using the median by sex and class.
# 3. A useful next step would be to analyze survival patterns with family composition, e.g., separating children, adults, and seniors within families.
#
# ### 🔎 Quick checks
# - Link the exact cell/table backing your claim.
# - Confirm deliverables (HTML + CSV) were written.

# %%
large_families = (df[df['family_size'] >= 4]
                  .groupby(['sex', 'class'], observed=False)
                  .agg(n=('survived', 'size'),
                       surv_rate=('survived', 'mean'))
                  .sort_values('surv_rate', ascending=False))
large_families.head(10)
large_families.to_csv('large_families.csv')
surv_by_fare_bucket.to_csv('survival_by_fare_bucket.csv')
df.to_html('titanic_cleaned.html')

# %% [markdown]
# ### ➕ Extension (pick one)
# - Add an extra feature (e.g., `is_child`, z-scored fare) and see if subgroup ranking changes.
# - Try a different minimum group size and discuss stability.
#
# **Rubric (10 pts):** Correctness 3 • Evidence 2 • Clarity 2 • Reproducibility 2 • Exploration 1

# %%
df['is_child'] = df['age'] <= 12
large_families_child = (df[df['family_size'] >= 4]
                        .groupby(['sex', 'class', 'is_child'],observed=False)
                        .agg(n=('survived','size'),
                             surv_rate=('survived','mean'))
                        .sort_values('surv_rate', ascending=False))
print("Survival ranking including 'is_child':\n", large_families_child.head(10))
